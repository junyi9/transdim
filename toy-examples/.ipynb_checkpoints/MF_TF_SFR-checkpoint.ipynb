# %% [markdown]
# # Low-Rank Matrix and Tensor Factorization for Speed Field Reconstruction
#
# - **Content**
#   - Matrix factorization with gradient descent (GD), steepest gradient descent (SGD), and alternating least squares (ALS)
#   - Hankel tensor factorization
#   - Applications: NGSIM speed field reconstruction \& Seattle freeway traffic speed imputation
#
# ## Matrix Factorization (MF)
#
# ### Gradient Descent (GD)

# %%
import numpy as np
np.random.seed(1)

def compute_mape(var, var_hat):
    return np.sum(np.abs(var - var_hat) / var) / var.shape[0]

def compute_rmse(var, var_hat):
    return np.sqrt(np.sum((var - var_hat) ** 2) / var.shape[0])

def MF_gd(dense_mat, sparse_mat, R, rho, alpha, maxiter = 100):
    N, T = sparse_mat.shape
    if np.isnan(sparse_mat).any() == False:
        ind = sparse_mat != 0
        pos_test = np.where((dense_mat != 0) & (sparse_mat == 0))
    elif np.isnan(sparse_mat).any() == True:
        ind = ~np.isnan(sparse_mat)
        pos_test = np.where((dense_mat > 0) & (np.isnan(sparse_mat)))
        sparse_mat[np.isnan(sparse_mat)] = 0
    W = 0.01 * np.random.randn(R, N)
    X = 0.01 * np.random.randn(R, T)
    obj = np.zeros(maxiter)
    show_iter = 10
    for it in range(maxiter):
        res_old = sparse_mat - W.T @ X
        grad_w = - X @ (res_old * ind).T + rho * W
        W = W - alpha * grad_w
        res_new = sparse_mat - W.T @ X
        grad_x = - W @ (res_new * ind) + rho * X
        X = X - alpha * grad_x
        mat_hat = W.T @ X
        obj[it] = (np.linalg.norm((sparse_mat - mat_hat) * ind, 'fro') ** 2 / 2
                   + rho * np.linalg.norm(W, 'fro') ** 2 / 2
                   + rho * np.linalg.norm(X, 'fro') ** 2 / 2)
        if (it + 1) % show_iter == 0:
            print('Iter: {}'.format(it + 1))
            print('Loss function: {:.6}'.format(obj[it]))
            print('MAPE: {:.6}'.format(compute_mape(dense_mat[pos_test], 
                                                    mat_hat[pos_test])))
            print('RMSE: {:.6}'.format(compute_rmse(dense_mat[pos_test], 
                                                    mat_hat[pos_test])))
            print()
    return mat_hat, obj

# %%
import numpy as np
np.random.seed(1)

import matplotlib.pyplot as plt
import seaborn as sns
import imageio as io
plt.rcParams['font.size'] = 12

dense_mat = np.load('../datasets/NGSIM-data-set/NGSIM_full.npy')
sparse_mat = np.load('../datasets/NGSIM-data-set/NGSIM_80missing.npy')

def plot_speed_field(data, filename):
    fig = plt.figure(figsize = (2.5 * 2.5, 2.5))
    plt.matshow(data, cmap='jet_r', origin='lower', 
                vmin = 0, vmax = 25, fignum = 1)
    plt.gca().xaxis.set_ticks_position('bottom')
    plt.xticks([0, 100, 200, 300, 400, 500], [0, 500, 1000, 1500, 2000, 2500])
    plt.yticks([0, 100, 200], [0, 300, 600])
    plt.xlabel('Time (s)')
    plt.ylabel('Location (m)')
    cbar = plt.colorbar(fraction = 0.015)
    cbar.ax.set_ylabel('Speed (mph)')
    plt.show()
    fig.savefig(filename, bbox_inches = 'tight', dpi = 300)

plot_speed_field(dense_mat, 'speed_field_fully_data.png')
plot_speed_field(sparse_mat, 'speed_field_80_missing_data.png')

import time
start = time.time()
R = 10
rho = 1e+1
alpha = 1e-4
maxiter = 1000
mat_hat, obj_gd = MF_gd(dense_mat, sparse_mat, R, rho, alpha, maxiter)
end = time.time()
print('Running time: %d seconds.'%(end - start))
plot_speed_field(mat_hat, 'speed_field_MF_gd_rec.png')
# Out:
# Iter: 10
# Loss function: 2.74568e+06
# MAPE: 1.0
# RMSE: 11.0812
#
# Iter: 20
# Loss function: 2.74505e+06
# MAPE: 0.999849
# RMSE: 11.0803
#
# Iter: 30
# Loss function: 2.72971e+06
# MAPE: 0.997032
# RMSE: 11.0571
#
# Iter: 40
# Loss function: 2.39307e+06
# MAPE: 0.955104
# RMSE: 10.5278
#
# Iter: 50
# Loss function: 5.56558e+05
# MAPE: 0.79384
# RMSE: 6.21654
#
# Iter: 60
# Loss function: 1.82547e+05
# MAPE: 0.889104
# RMSE: 3.81154
#
# Iter: 70
# Loss function: 1.58247e+05
# MAPE: 0.929745
# RMSE: 3.37007
#
# Iter: 80
# Loss function: 1.53881e+05
# MAPE: 0.939031
# RMSE: 3.2293
#
# Iter: 90
# Loss function: 1.52603e+05
# MAPE: 0.94127
# RMSE: 3.16737
#
# Iter: 100
# Loss function: 1.52089e+05
# MAPE: 0.941734
# RMSE: 3.13364
#
# Iter: 110
# Loss function: 1.51807e+05
# MAPE: 0.941669
# RMSE: 3.11205
#
# Iter: 120
# Loss function: 1.51587e+05
# MAPE: 0.941435
# RMSE: 3.09643
#
# Iter: 130
# Loss function: 1.51356e+05
# MAPE: 0.941062
# RMSE: 3.084
#
# Iter: 140
# Loss function: 1.51069e+05
# MAPE: 0.940551
# RMSE: 3.07328
#
# Iter: 150
# Loss function: 1.50679e+05
# MAPE: 0.939864
# RMSE: 3.06334
#
# Iter: 160
# Loss function: 1.50132e+05
# MAPE: 0.938932
# RMSE: 3.05342
#
# Iter: 170
# Loss function: 1.49355e+05
# MAPE: 0.937645
# RMSE: 3.04277
#
# Iter: 180
# Loss function: 1.48251e+05
# MAPE: 0.935845
# RMSE: 3.0305
#
# Iter: 190
# Loss function: 1.46695e+05
# MAPE: 0.933308
# RMSE: 3.01553
#
# Iter: 200
# Loss function: 1.4454e+05
# MAPE: 0.929741
# RMSE: 2.99656
#
# Iter: 210
# Loss function: 1.41628e+05
# MAPE: 0.924773
# RMSE: 2.97215
#
# Iter: 220
# Loss function: 1.37836e+05
# MAPE: 0.917987
# RMSE: 2.94091
#
# Iter: 230
# Loss function: 1.3314e+05
# MAPE: 0.908988
# RMSE: 2.902
#
# Iter: 240
# Loss function: 1.2768e+05
# MAPE: 0.897532
# RMSE: 2.85569
#
# Iter: 250
# Loss function: 1.21789e+05
# MAPE: 0.883674
# RMSE: 2.80389
#
# Iter: 260
# Loss function: 1.15922e+05
# MAPE: 0.867848
# RMSE: 2.74995
#
# Iter: 270
# Loss function: 1.10508e+05
# MAPE: 0.850717
# RMSE: 2.69774
#
# Iter: 280
# Loss function: 1.05796e+05
# MAPE: 0.833074
# RMSE: 2.65031
#
# Iter: 290
# Loss function: 1.0182e+05
# MAPE: 0.815603
# RMSE: 2.60905
#
# Iter: 300
# Loss function: 98461.7
# MAPE: 0.798649
# RMSE: 2.57374
#
# Iter: 310
# Loss function: 95554.3
# MAPE: 0.782328
# RMSE: 2.54326
#
# Iter: 320
# Loss function: 92952.3
# MAPE: 0.766603
# RMSE: 2.51636
#
# Iter: 330
# Loss function: 90562.6
# MAPE: 0.751436
# RMSE: 2.49204
#
# Iter: 340
# Loss function: 88342.0
# MAPE: 0.736811
# RMSE: 2.46974
#
# Iter: 350
# Loss function: 86282.8
# MAPE: 0.722754
# RMSE: 2.44929
#
# Iter: 360
# Loss function: 84394.2
# MAPE: 0.709349
# RMSE: 2.43073
#
# Iter: 370
# Loss function: 82687.7
# MAPE: 0.696685
# RMSE: 2.4142
#
# Iter: 380
# Loss function: 81166.2
# MAPE: 0.684839
# RMSE: 2.39979
#
# Iter: 390
# Loss function: 79821.5
# MAPE: 0.673894
# RMSE: 2.38748
#
# Iter: 400
# Loss function: 78635.3
# MAPE: 0.663895
# RMSE: 2.37715
#
# Iter: 410
# Loss function: 77583.2
# MAPE: 0.654832
# RMSE: 2.36856
#
# Iter: 420
# Loss function: 76640.0
# MAPE: 0.646667
# RMSE: 2.36141
#
# Iter: 430
# Loss function: 75782.3
# MAPE: 0.639353
# RMSE: 2.35541
#
# Iter: 440
# Loss function: 74991.3
# MAPE: 0.632798
# RMSE: 2.35029
#
# Iter: 450
# Loss function: 74252.9
# MAPE: 0.626905
# RMSE: 2.34582
#
# Iter: 460
# Loss function: 73557.4
# MAPE: 0.621585
# RMSE: 2.34182
#
# Iter: 470
# Loss function: 72899.3
# MAPE: 0.616756
# RMSE: 2.33815
#
# Iter: 480
# Loss function: 72275.4
# MAPE: 0.612349
# RMSE: 2.33474
#
# Iter: 490
# Loss function: 71684.7
# MAPE: 0.6083
# RMSE: 2.33153
#
# Iter: 500
# Loss function: 71126.9
# MAPE: 0.60456
# RMSE: 2.32851
#
# Iter: 510
# Loss function: 70602.1
# MAPE: 0.601088
# RMSE: 2.32566
#
# Iter: 520
# Loss function: 70110.2
# MAPE: 0.597833
# RMSE: 2.323
#
# Iter: 530
# Loss function: 69650.3
# MAPE: 0.594767
# RMSE: 2.32053
#
# Iter: 540
# Loss function: 69221.2
# MAPE: 0.591859
# RMSE: 2.31825
#
# Iter: 550
# Loss function: 68820.9
# MAPE: 0.589094
# RMSE: 2.31619
#
# Iter: 560
# Loss function: 68447.1
# MAPE: 0.586456
# RMSE: 2.31433
#
# Iter: 570
# Loss function: 68097.1
# MAPE: 0.583922
# RMSE: 2.31267
#
# Iter: 580
# Loss function: 67768.2
# MAPE: 0.581478
# RMSE: 2.3112
#
# Iter: 590
# Loss function: 67457.8
# MAPE: 0.579114
# RMSE: 2.30991
#
# Iter: 600
# Loss function: 67163.2
# MAPE: 0.576816
# RMSE: 2.30879
#
# Iter: 610
# Loss function: 66882.3
# MAPE: 0.574568
# RMSE: 2.30782
#
# Iter: 620
# Loss function: 66613.1
# MAPE: 0.572365
# RMSE: 2.30699
#
# Iter: 630
# Loss function: 66354.1
# MAPE: 0.5702
# RMSE: 2.30627
#
# Iter: 640
# Loss function: 66104.0
# MAPE: 0.568064
# RMSE: 2.30567
#
# Iter: 650
# Loss function: 65861.7
# MAPE: 0.565954
# RMSE: 2.30516
#
# Iter: 660
# Loss function: 65626.4
# MAPE: 0.563863
# RMSE: 2.30474
#
# Iter: 670
# Loss function: 65397.7
# MAPE: 0.561795
# RMSE: 2.3044
#
# Iter: 680
# Loss function: 65175.1
# MAPE: 0.559744
# RMSE: 2.30413
#
# Iter: 690
# Loss function: 64958.4
# MAPE: 0.55771
# RMSE: 2.30394
#
# Iter: 700
# Loss function: 64747.3
# MAPE: 0.555693
# RMSE: 2.30381
#
# Iter: 710
# Loss function: 64541.9
# MAPE: 0.55369
# RMSE: 2.30375
#
# Iter: 720
# Loss function: 64342.0
# MAPE: 0.551704
# RMSE: 2.30376
#
# Iter: 730
# Loss function: 64147.6
# MAPE: 0.549733
# RMSE: 2.30384
#
# Iter: 740
# Loss function: 63958.7
# MAPE: 0.54778
# RMSE: 2.30398
#
# Iter: 750
# Loss function: 63775.2
# MAPE: 0.545843
# RMSE: 2.30419
#
# Iter: 760
# Loss function: 63597.1
# MAPE: 0.543923
# RMSE: 2.30446
#
# Iter: 770
# Loss function: 63424.3
# MAPE: 0.542025
# RMSE: 2.30481
#
# Iter: 780
# Loss function: 63256.7
# MAPE: 0.540152
# RMSE: 2.30523
#
# Iter: 790
# Loss function: 63094.2
# MAPE: 0.538307
# RMSE: 2.30571
#
# Iter: 800
# Loss function: 62936.6
# MAPE: 0.536489
# RMSE: 2.30627
#
# Iter: 810
# Loss function: 62783.7
# MAPE: 0.5347
# RMSE: 2.3069
#
# Iter: 820
# Loss function: 62635.4
# MAPE: 0.53294
# RMSE: 2.30759
#
# Iter: 830
# Loss function: 62491.5
# MAPE: 0.53121
# RMSE: 2.30835
#
# Iter: 840
# Loss function: 62351.8
# MAPE: 0.529511
# RMSE: 2.30918
#
# Iter: 850
# Loss function: 62216.1
# MAPE: 0.527844
# RMSE: 2.31008
#
# Iter: 860
# Loss function: 62084.3
# MAPE: 0.52621
# RMSE: 2.31104
#
# Iter: 870
# Loss function: 61956.1
# MAPE: 0.524608
# RMSE: 2.31206
#
# Iter: 880
# Loss function: 61831.5
# MAPE: 0.523042
# RMSE: 2.31313
#
# Iter: 890
# Loss function: 61710.3
# MAPE: 0.521507
# RMSE: 2.31427
#
# Iter: 900
# Loss function: 61592.2
# MAPE: 0.520004
# RMSE: 2.31546
#
# Iter: 910
# Loss function: 61477.4
# MAPE: 0.518532
# RMSE: 2.31671
#
# Iter: 920
# Loss function: 61365.5
# MAPE: 0.517092
# RMSE: 2.31801
#
# Iter: 930
# Loss function: 61256.6
# MAPE: 0.515683
# RMSE: 2.31936
#
# Iter: 940
# Loss function: 61150.5
# MAPE: 0.514305
# RMSE: 2.32076
#
# Iter: 950
# Loss function: 61047.2
# MAPE: 0.512958
# RMSE: 2.3222
#
# Iter: 960
# Loss function: 60946.6
# MAPE: 0.51164
# RMSE: 2.32369
#
# Iter: 970
# Loss function: 60848.7
# MAPE: 0.510349
# RMSE: 2.32523
#
# Iter: 980
# Loss function: 60753.3
# MAPE: 0.509087
# RMSE: 2.3268
#
# Iter: 990
# Loss function: 60660.5
# MAPE: 0.507854
# RMSE: 2.32842
#
# Iter: 1000
# Loss function: 60570.2
# MAPE: 0.506647
# RMSE: 2.33008
#
# Running time: 9 seconds.

# %% [markdown]
# ### Matrix Factorization with Steepest Gradient Descent (SGD)

# %%
import numpy as np
np.random.seed(1)

def compute_mape(var, var_hat):
    return np.sum(np.abs(var - var_hat) / var) / var.shape[0]

def compute_rmse(var, var_hat):
    return np.sqrt(np.sum((var - var_hat) ** 2) / var.shape[0])

def MF_sgd(dense_mat, sparse_mat, R, rho, maxiter = 100):
    N, T = sparse_mat.shape
    if np.isnan(sparse_mat).any() == False:
        ind = sparse_mat != 0
        pos_test = np.where((dense_mat != 0) & (sparse_mat == 0))
    elif np.isnan(sparse_mat).any() == True:
        ind = ~np.isnan(sparse_mat)
        pos_test = np.where((dense_mat > 0) & (np.isnan(sparse_mat)))
        sparse_mat[np.isnan(sparse_mat)] = 0
    W = 0.01 * np.random.randn(R, N)
    X = 0.01 * np.random.randn(R, T)
    obj = np.zeros(maxiter)
    show_iter = 10
    for it in range(maxiter):
        res_old = sparse_mat - W.T @ X
        grad_w = - X @ (res_old * ind).T + rho * W
        a1 = (np.linalg.norm((grad_w.T @ X) * ind, 'fro') ** 2
              + rho * np.linalg.norm(grad_w, 'fro') ** 2)
        a2 = - np.sum(res_old * (grad_w.T @ X) * ind) + rho * np.sum(W * grad_w)
        alpha = a2 / a1
        W = W - alpha * grad_w
        res_new = sparse_mat - W.T @ X
        grad_x = - W @ (res_new * ind) + rho * X
        b1 = (np.linalg.norm((W.T @ grad_x) * ind, 'fro') ** 2
              + rho * np.linalg.norm(grad_x, 'fro') ** 2)
        b2 = - np.sum(res_new * (W.T @ grad_x) * ind) + rho * np.sum(X * grad_x)
        beta = b2 / b1
        X = X - beta * grad_x
        mat_hat = W.T @ X
        obj[it] = (np.linalg.norm((sparse_mat - mat_hat) * ind, 'fro') ** 2 / 2
                   + rho * np.linalg.norm(W, 'fro') ** 2 / 2
                   + rho * np.linalg.norm(X, 'fro') ** 2 / 2)
        if (it + 1) % show_iter == 0:
            print('Iter: {}'.format(it + 1))
            print('Loss function: {:.6}'.format(obj[it]))
            print('MAPE: {:.6}'.format(compute_mape(dense_mat[pos_test], 
                                                    mat_hat[pos_test])))
            print('RMSE: {:.6}'.format(compute_rmse(dense_mat[pos_test], 
                                                    mat_hat[pos_test])))
            print()
    return mat_hat, obj

# %%
import numpy as np
np.random.seed(1)

import matplotlib.pyplot as plt
import seaborn as sns
import imageio as io
plt.rcParams['font.size'] = 12

dense_mat = np.load('../datasets/NGSIM-data-set/NGSIM_full.npy')
sparse_mat = np.load('../datasets/NGSIM-data-set/NGSIM_80missing.npy')

def plot_speed_field(data, filename):
    fig = plt.figure(figsize = (2.5 * 2.5, 2.5))
    plt.matshow(data, cmap='jet_r', origin='lower', 
                vmin = 0, vmax = 25, fignum = 1)
    plt.gca().xaxis.set_ticks_position('bottom')
    plt.xticks([0, 100, 200, 300, 400, 500], [0, 500, 1000, 1500, 2000, 2500])
    plt.yticks([0, 100, 200], [0, 300, 600])
    plt.xlabel('Time (s)')
    plt.ylabel('Location (m)')
    cbar = plt.colorbar(fraction = 0.015)
    cbar.ax.set_ylabel('Speed (mph)')
    plt.show()
    fig.savefig(filename, bbox_inches = 'tight', dpi = 300)

plot_speed_field(dense_mat, 'speed_field_fully_data.png')
plot_speed_field(sparse_mat, 'speed_field_80_missing_data.png')

import time
start = time.time()
R = 10
rho = 1e+1
maxiter = 1000
mat_hat, obj_sgd = MF_sgd(dense_mat, sparse_mat, R, rho, maxiter)
end = time.time()
print('Running time: %d seconds.'%(end - start))
plot_speed_field(mat_hat, 'speed_field_MF_sgd_rec.png')
# Out:
# Iter: 10
# Loss function: 1.93342e+05
# MAPE: 0.800192
# RMSE: 3.10505
#
# Iter: 20
# Loss function: 1.01644e+05
# MAPE: 0.66739
# RMSE: 2.73654
#
# Iter: 30
# Loss function: 78439.3
# MAPE: 0.601586
# RMSE: 2.61519
#
# Iter: 40
# Loss function: 69530.2
# MAPE: 0.572334
# RMSE: 2.56044
#
# Iter: 50
# Loss function: 65030.8
# MAPE: 0.552857
# RMSE: 2.5368
#
# Iter: 60
# Loss function: 62442.1
# MAPE: 0.53718
# RMSE: 2.52508
#
# Iter: 70
# Loss function: 60949.7
# MAPE: 0.524547
# RMSE: 2.52385
#
# Iter: 80
# Loss function: 60036.1
# MAPE: 0.514466
# RMSE: 2.52928
#
# Iter: 90
# Loss function: 59403.9
# MAPE: 0.50605
# RMSE: 2.53768
#
# Iter: 100
# Loss function: 58942.4
# MAPE: 0.498991
# RMSE: 2.54735
#
# Iter: 110
# Loss function: 58598.3
# MAPE: 0.492929
# RMSE: 2.55764
#
# Iter: 120
# Loss function: 58339.5
# MAPE: 0.487617
# RMSE: 2.56843
#
# Iter: 130
# Loss function: 58144.0
# MAPE: 0.482966
# RMSE: 2.57954
#
# Iter: 140
# Loss function: 57995.2
# MAPE: 0.478932
# RMSE: 2.5907
#
# Iter: 150
# Loss function: 57880.3
# MAPE: 0.475442
# RMSE: 2.60175
#
# Iter: 160
# Loss function: 57790.0
# MAPE: 0.472402
# RMSE: 2.61258
#
# Iter: 170
# Loss function: 57717.7
# MAPE: 0.469756
# RMSE: 2.62312
#
# Iter: 180
# Loss function: 57658.8
# MAPE: 0.467438
# RMSE: 2.63335
#
# Iter: 190
# Loss function: 57610.1
# MAPE: 0.465398
# RMSE: 2.64323
#
# Iter: 200
# Loss function: 57569.4
# MAPE: 0.463594
# RMSE: 2.65275
#
# Iter: 210
# Loss function: 57534.8
# MAPE: 0.461997
# RMSE: 2.66189
#
# Iter: 220
# Loss function: 57505.2
# MAPE: 0.460583
# RMSE: 2.67063
#
# Iter: 230
# Loss function: 57479.7
# MAPE: 0.459329
# RMSE: 2.67899
#
# Iter: 240
# Loss function: 57457.4
# MAPE: 0.458215
# RMSE: 2.68695
#
# Iter: 250
# Loss function: 57437.9
# MAPE: 0.457225
# RMSE: 2.69452
#
# Iter: 260
# Loss function: 57420.7
# MAPE: 0.456347
# RMSE: 2.70169
#
# Iter: 270
# Loss function: 57405.5
# MAPE: 0.455571
# RMSE: 2.70846
#
# Iter: 280
# Loss function: 57392.0
# MAPE: 0.454885
# RMSE: 2.71485
#
# Iter: 290
# Loss function: 57380.0
# MAPE: 0.454283
# RMSE: 2.72085
#
# Iter: 300
# Loss function: 57369.2
# MAPE: 0.453757
# RMSE: 2.72646
#
# Iter: 310
# Loss function: 57359.6
# MAPE: 0.453298
# RMSE: 2.73169
#
# Iter: 320
# Loss function: 57351.0
# MAPE: 0.452899
# RMSE: 2.73656
#
# Iter: 330
# Loss function: 57343.2
# MAPE: 0.452558
# RMSE: 2.74106
#
# Iter: 340
# Loss function: 57336.3
# MAPE: 0.452268
# RMSE: 2.74522
#
# Iter: 350
# Loss function: 57330.0
# MAPE: 0.452025
# RMSE: 2.74904
#
# Iter: 360
# Loss function: 57324.4
# MAPE: 0.451824
# RMSE: 2.75255
#
# Iter: 370
# Loss function: 57319.3
# MAPE: 0.451657
# RMSE: 2.75575
#
# Iter: 380
# Loss function: 57314.7
# MAPE: 0.45152
# RMSE: 2.75868
#
# Iter: 390
# Loss function: 57310.5
# MAPE: 0.451408
# RMSE: 2.76134
#
# Iter: 400
# Loss function: 57306.8
# MAPE: 0.451317
# RMSE: 2.76376
#
# Iter: 410
# Loss function: 57303.3
# MAPE: 0.451245
# RMSE: 2.76595
#
# Iter: 420
# Loss function: 57300.2
# MAPE: 0.451187
# RMSE: 2.76794
#
# Iter: 430
# Loss function: 57297.4
# MAPE: 0.451142
# RMSE: 2.76974
#
# Iter: 440
# Loss function: 57294.9
# MAPE: 0.451108
# RMSE: 2.77137
#
# Iter: 450
# Loss function: 57292.5
# MAPE: 0.451084
# RMSE: 2.77283
#
# Iter: 460
# Loss function: 57290.4
# MAPE: 0.451068
# RMSE: 2.77416
#
# Iter: 470
# Loss function: 57288.5
# MAPE: 0.451058
# RMSE: 2.77535
#
# Iter: 480
# Loss function: 57286.7
# MAPE: 0.451052
# RMSE: 2.77643
#
# Iter: 490
# Loss function: 57285.0
# MAPE: 0.451051
# RMSE: 2.7774
#
# Iter: 500
# Loss function: 57283.5
# MAPE: 0.451052
# RMSE: 2.77827
#
# Iter: 510
# Loss function: 57282.2
# MAPE: 0.451055
# RMSE: 2.77906
#
# Iter: 520
# Loss function: 57280.9
# MAPE: 0.45106
# RMSE: 2.77978
#
# Iter: 530
# Loss function: 57279.7
# MAPE: 0.451066
# RMSE: 2.78042
#
# Iter: 540
# Loss function: 57278.7
# MAPE: 0.451073
# RMSE: 2.781
#
# Iter: 550
# Loss function: 57277.7
# MAPE: 0.451081
# RMSE: 2.78153
#
# Iter: 560
# Loss function: 57276.7
# MAPE: 0.451088
# RMSE: 2.78201
#
# Iter: 570
# Loss function: 57275.9
# MAPE: 0.451096
# RMSE: 2.78244
#
# Iter: 580
# Loss function: 57275.1
# MAPE: 0.451104
# RMSE: 2.78284
#
# Iter: 590
# Loss function: 57274.3
# MAPE: 0.451112
# RMSE: 2.7832
#
# Iter: 600
# Loss function: 57273.6
# MAPE: 0.45112
# RMSE: 2.78352
#
# Iter: 610
# Loss function: 57273.0
# MAPE: 0.451127
# RMSE: 2.78382
#
# Iter: 620
# Loss function: 57272.4
# MAPE: 0.451134
# RMSE: 2.7841
#
# Iter: 630
# Loss function: 57271.8
# MAPE: 0.451141
# RMSE: 2.78435
#
# Iter: 640
# Loss function: 57271.3
# MAPE: 0.451147
# RMSE: 2.78459
#
# Iter: 650
# Loss function: 57270.8
# MAPE: 0.451153
# RMSE: 2.7848
#
# Iter: 660
# Loss function: 57270.3
# MAPE: 0.451159
# RMSE: 2.785
#
# Iter: 670
# Loss function: 57269.8
# MAPE: 0.451165
# RMSE: 2.78519
#
# Iter: 680
# Loss function: 57269.4
# MAPE: 0.451171
# RMSE: 2.78536
#
# Iter: 690
# Loss function: 57269.0
# MAPE: 0.451177
# RMSE: 2.78552
#
# Iter: 700
# Loss function: 57268.6
# MAPE: 0.451182
# RMSE: 2.78567
#
# Iter: 710
# Loss function: 57268.2
# MAPE: 0.451187
# RMSE: 2.78581
#
# Iter: 720
# Loss function: 57267.9
# MAPE: 0.451192
# RMSE: 2.78594
#
# Iter: 730
# Loss function: 57267.5
# MAPE: 0.451197
# RMSE: 2.78606
#
# Iter: 740
# Loss function: 57267.2
# MAPE: 0.451202
# RMSE: 2.78617
#
# Iter: 750
# Loss function: 57266.9
# MAPE: 0.451206
# RMSE: 2.78628
#
# Iter: 760
# Loss function: 57266.6
# MAPE: 0.451211
# RMSE: 2.78638
#
# Iter: 770
# Loss function: 57266.3
# MAPE: 0.451216
# RMSE: 2.78648
#
# Iter: 780
# Loss function: 57266.0
# MAPE: 0.45122
# RMSE: 2.78657
#
# Iter: 790
# Loss function: 57265.7
# MAPE: 0.451224
# RMSE: 2.78665
#
# Iter: 800
# Loss function: 57265.4
# MAPE: 0.451229
# RMSE: 2.78673
#
# Iter: 810
# Loss function: 57265.2
# MAPE: 0.451233
# RMSE: 2.78681
#
# Iter: 820
# Loss function: 57264.9
# MAPE: 0.451237
# RMSE: 2.78688
#
# Iter: 830
# Loss function: 57264.7
# MAPE: 0.451241
# RMSE: 2.78695
#
# Iter: 840
# Loss function: 57264.5
# MAPE: 0.451245
# RMSE: 2.78701
#
# Iter: 850
# Loss function: 57264.2
# MAPE: 0.45125
# RMSE: 2.78707
#
# Iter: 860
# Loss function: 57264.0
# MAPE: 0.451254
# RMSE: 2.78713
#
# Iter: 870
# Loss function: 57263.8
# MAPE: 0.451258
# RMSE: 2.78719
#
# Iter: 880
# Loss function: 57263.6
# MAPE: 0.451262
# RMSE: 2.78724
#
# Iter: 890
# Loss function: 57263.4
# MAPE: 0.451265
# RMSE: 2.78729
#
# Iter: 900
# Loss function: 57263.2
# MAPE: 0.451269
# RMSE: 2.78733
#
# Iter: 910
# Loss function: 57263.0
# MAPE: 0.451273
# RMSE: 2.78738
#
# Iter: 920
# Loss function: 57262.9
# MAPE: 0.451277
# RMSE: 2.78742
#
# Iter: 930
# Loss function: 57262.7
# MAPE: 0.45128
# RMSE: 2.78746
#
# Iter: 940
# Loss function: 57262.5
# MAPE: 0.451284
# RMSE: 2.7875
#
# Iter: 950
# Loss function: 57262.4
# MAPE: 0.451288
# RMSE: 2.78753
#
# Iter: 960
# Loss function: 57262.2
# MAPE: 0.451292
# RMSE: 2.78757
#
# Iter: 970
# Loss function: 57262.0
# MAPE: 0.451296
# RMSE: 2.7876
#
# Iter: 980
# Loss function: 57261.9
# MAPE: 0.451299
# RMSE: 2.78763
#
# Iter: 990
# Loss function: 57261.8
# MAPE: 0.451303
# RMSE: 2.78766
#
# Iter: 1000
# Loss function: 57261.6
# MAPE: 0.451307
# RMSE: 2.78769
#
# Running time: 15 seconds.

# %% [markdown]
# ### Matrix Factorization with Alternating Least Squares (ALS)

# %%
import numpy as np
np.random.randn(1)

def compute_mape(var, var_hat):
    return np.sum(np.abs(var - var_hat) / var) / var.shape[0]

def compute_rmse(var, var_hat):
    return np.sqrt(np.sum((var - var_hat) ** 2) / var.shape[0])

def MF_als(dense_mat, sparse_mat, R, rho, maxiter = 100):
    N, T = sparse_mat.shape
    if np.isnan(sparse_mat).any() == False:
        ind = sparse_mat != 0
        pos_test = np.where((dense_mat != 0) & (sparse_mat == 0))
    elif np.isnan(sparse_mat).any() == True:
        ind = ~np.isnan(sparse_mat)
        pos_test = np.where((dense_mat > 0) & (np.isnan(sparse_mat)))
        sparse_mat[np.isnan(sparse_mat)] = 0
    W = 0.01 * np.random.randn(R, N)
    X = 0.01 * np.random.randn(R, T)
    obj = np.zeros(maxiter)
    show_iter = 10
    for it in range(maxiter):
        for i in range(N):
            pos0 = np.where(sparse_mat[i, :] != 0)
            Xt = X[:, pos0[0]]
            W[:, i] = np.linalg.solve(Xt @ Xt.T + rho * np.eye(R), 
                                      Xt @ sparse_mat[i, pos0[0]])
        for t in range(T):
            pos0 = np.where(sparse_mat[:, t] != 0)
            Wi = W[:, pos0[0]]
            X[:, t] = np.linalg.solve(Wi @ Wi.T + rho * np.eye(R), 
                                      Wi @ sparse_mat[pos0[0], t])
        mat_hat = W.T @ X
        obj[it] = (np.linalg.norm((sparse_mat - mat_hat) * ind, 'fro') ** 2 / 2
                   + rho * np.linalg.norm(W, 'fro') ** 2 / 2
                   + rho * np.linalg.norm(X, 'fro') ** 2 / 2)
        if (it + 1) % show_iter == 0:
            print('Iter: {}'.format(it + 1))
            print('Loss function: {:.6}'.format(obj[it]))
            print('MAPE: {:.6}'.format(compute_mape(dense_mat[pos_test], 
                                                    mat_hat[pos_test])))
            print('RMSE: {:.6}'.format(compute_rmse(dense_mat[pos_test], 
                                                    mat_hat[pos_test])))
            print()
    return mat_hat, obj

# %%
import numpy as np
np.random.seed(1)

import matplotlib.pyplot as plt
import seaborn as sns
import imageio as io
plt.rcParams['font.size'] = 12

dense_mat = np.load('../datasets/NGSIM-data-set/NGSIM_full.npy')
sparse_mat = np.load('../datasets/NGSIM-data-set/NGSIM_80missing.npy')

def plot_speed_field(data, filename):
    fig = plt.figure(figsize = (2.5 * 2.5, 2.5))
    plt.matshow(data, cmap='jet_r', origin='lower', 
                vmin = 0, vmax = 25, fignum = 1)
    plt.gca().xaxis.set_ticks_position('bottom')
    plt.xticks([0, 100, 200, 300, 400, 500], [0, 500, 1000, 1500, 2000, 2500])
    plt.yticks([0, 100, 200], [0, 300, 600])
    plt.xlabel('Time (s)')
    plt.ylabel('Location (m)')
    cbar = plt.colorbar(fraction = 0.015)
    cbar.ax.set_ylabel('Speed (mph)')
    plt.show()
    fig.savefig(filename, bbox_inches = 'tight', dpi = 300)

plot_speed_field(dense_mat, 'speed_field_fully_data.png')
plot_speed_field(sparse_mat, 'speed_field_80_missing_data.png')

import time
start = time.time()
R = 10
rho = 1e+1
maxiter = 200
mat_hat, obj_als = MF_als(dense_mat, sparse_mat, R, rho, maxiter)
end = time.time()
print('Running time: %d seconds.'%(end - start))
plot_speed_field(mat_hat, 'speed_field_MF_als_rec.png')
# Out:
# Iter: 10
# Loss function: 1.26071e+05
# MAPE: 0.584683
# RMSE: 5.51965
#
# Iter: 20
# Loss function: 83646.3
# MAPE: 0.520906
# RMSE: 4.50491
#
# Iter: 30
# Loss function: 70300.6
# MAPE: 0.493598
# RMSE: 3.92371
#
# Iter: 40
# Loss function: 64319.4
# MAPE: 0.479866
# RMSE: 3.56566
#
# Iter: 50
# Loss function: 61244.6
# MAPE: 0.472314
# RMSE: 3.3352
#
# Iter: 60
# Loss function: 59559.9
# MAPE: 0.467821
# RMSE: 3.18131
#
# Iter: 70
# Loss function: 58606.0
# MAPE: 0.464977
# RMSE: 3.0753
#
# Iter: 80
# Loss function: 58056.2
# MAPE: 0.46308
# RMSE: 3.00049
#
# Iter: 90
# Loss function: 57736.3
# MAPE: 0.461779
# RMSE: 2.94667
#
# Iter: 100
# Loss function: 57549.1
# MAPE: 0.460867
# RMSE: 2.90738
#
# Iter: 110
# Loss function: 57439.4
# MAPE: 0.460208
# RMSE: 2.87837
#
# Iter: 120
# Loss function: 57374.9
# MAPE: 0.459725
# RMSE: 2.85675
#
# Iter: 130
# Loss function: 57337.0
# MAPE: 0.459366
# RMSE: 2.84053
#
# Iter: 140
# Loss function: 57314.8
# MAPE: 0.459096
# RMSE: 2.8283
#
# Iter: 150
# Loss function: 57301.7
# MAPE: 0.458891
# RMSE: 2.81903
#
# Iter: 160
# Loss function: 57294.0
# MAPE: 0.458736
# RMSE: 2.812
#
# Iter: 170
# Loss function: 57289.5
# MAPE: 0.458617
# RMSE: 2.80664
#
# Iter: 180
# Loss function: 57286.9
# MAPE: 0.458527
# RMSE: 2.80255
#
# Iter: 190
# Loss function: 57285.3
# MAPE: 0.458457
# RMSE: 2.79943
#
# Iter: 200
# Loss function: 57284.4
# MAPE: 0.458404
# RMSE: 2.79704
#
# Running time: 4 seconds.

# %% [markdown]
# ### Objective Function $f$ vs. Iteration

# %%
import matplotlib.pyplot as plt
plt.rcParams['mathtext.fontset'] = 'cm'

show_it = 200
fig = plt.figure(figsize = (4, 3.5))
plt.yscale("log")
plt.plot(obj_gd, 'blue', linewidth = 2.5)
plt.plot(obj_sgd, 'green', linewidth = 2.5)
plt.plot(obj_als, 'red', linewidth = 2.5)
plt.xlim([0, show_it])
plt.xlabel('Iteration')
plt.ylabel(r'Objective function $f$')
plt.legend(['GD', 'SGD', 'ALS'])
plt.savefig("MF_convergence_over_gd_and_als_within_{}iter.pdf".format(show_it), 
            format = "pdf", bbox_inches = "tight")
plt.show()

# %% [markdown]
# ### Seattle Freeway Traffic Speed Imputation
#
# #### Matrix Factorization with GD

# %%
import numpy as np
np.random.seed(1000)

dense_tensor = np.load('../datasets/Seattle-data-set/tensor.npz')['arr_0']
dim = dense_tensor.shape
missing_rate = 0.6 # Random missing (RM)
sparse_tensor = dense_tensor * np.round(np.random.rand(dim[0], dim[1], dim[2]) + 0.5 - missing_rate)
dense_mat = dense_tensor.reshape([dim[0], dim[1] * dim[2]])
sparse_mat = sparse_tensor.reshape([dim[0], dim[1] * dim[2]])
del dense_tensor, sparse_tensor

import time
start = time.time()
R = 10
rho = 1e+2
alpha = 2e-5
maxiter = 1000
mat_hat, obj_gd = MF_gd(dense_mat, sparse_mat, R, rho, alpha, maxiter)
end = time.time()
print('Running time: %d seconds.'%(end - start))
# Out:
# Iter: 10
# Loss function: 1.73798e+09
# MAPE: 0.982976
# RMSE: 57.793
#
# Iter: 20
# Loss function: 4.7263e+07
# MAPE: 0.183475
# RMSE: 8.5812
#
# Iter: 30
# Loss function: 4.72629e+07
# MAPE: 0.183475
# RMSE: 8.58118
#
# Iter: 40
# Loss function: 4.72627e+07
# MAPE: 0.183475
# RMSE: 8.58117
#
# Iter: 50
# Loss function: 4.72624e+07
# MAPE: 0.183475
# RMSE: 8.58115
#
# Iter: 60
# Loss function: 4.72617e+07
# MAPE: 0.183473
# RMSE: 8.58107
#
# Iter: 70
# Loss function: 4.72598e+07
# MAPE: 0.183468
# RMSE: 8.58087
#
# Iter: 80
# Loss function: 4.72547e+07
# MAPE: 0.183456
# RMSE: 8.58032
#
# Iter: 90
# Loss function: 4.72407e+07
# MAPE: 0.183422
# RMSE: 8.57877
#
# Iter: 100
# Loss function: 4.72013e+07
# MAPE: 0.183326
# RMSE: 8.57442
#
# Iter: 110
# Loss function: 4.709e+07
# MAPE: 0.183057
# RMSE: 8.56211
#
# Iter: 120
# Loss function: 4.67761e+07
# MAPE: 0.182302
# RMSE: 8.5272
#
# Iter: 130
# Loss function: 4.59122e+07
# MAPE: 0.180206
# RMSE: 8.43016
#
# Iter: 140
# Loss function: 4.37398e+07
# MAPE: 0.174734
# RMSE: 8.17997
#
# Iter: 150
# Loss function: 3.94844e+07
# MAPE: 0.16272
# RMSE: 7.6613
#
# Iter: 160
# Loss function: 3.4494e+07
# MAPE: 0.144559
# RMSE: 6.98982
#
# Iter: 170
# Loss function: 3.15637e+07
# MAPE: 0.128993
# RMSE: 6.54415
#
# Iter: 180
# Loss function: 3.05939e+07
# MAPE: 0.121617
# RMSE: 6.37709
#
# Iter: 190
# Loss function: 3.03524e+07
# MAPE: 0.11912
# RMSE: 6.32952
#
# Iter: 200
# Loss function: 3.02892e+07
# MAPE: 0.118275
# RMSE: 6.3155
#
# Iter: 210
# Loss function: 3.02609e+07
# MAPE: 0.117932
# RMSE: 6.3095
#
# Iter: 220
# Loss function: 3.02337e+07
# MAPE: 0.11774
# RMSE: 6.30474
#
# Iter: 230
# Loss function: 3.01953e+07
# MAPE: 0.117568
# RMSE: 6.29877
#
# Iter: 240
# Loss function: 3.01361e+07
# MAPE: 0.117351
# RMSE: 6.28993
#
# Iter: 250
# Loss function: 3.00445e+07
# MAPE: 0.117032
# RMSE: 6.27638
#
# Iter: 260
# Loss function: 2.99069e+07
# MAPE: 0.116553
# RMSE: 6.256
#
# Iter: 270
# Loss function: 2.97108e+07
# MAPE: 0.115852
# RMSE: 6.22674
#
# Iter: 280
# Loss function: 2.94525e+07
# MAPE: 0.114886
# RMSE: 6.18777
#
# Iter: 290
# Loss function: 2.91479e+07
# MAPE: 0.113669
# RMSE: 6.14103
#
# Iter: 300
# Loss function: 2.88338e+07
# MAPE: 0.112297
# RMSE: 6.09183
#
# Iter: 310
# Loss function: 2.8552e+07
# MAPE: 0.110935
# RMSE: 6.04664
#
# Iter: 320
# Loss function: 2.83232e+07
# MAPE: 0.109739
# RMSE: 6.00921
#
# Iter: 330
# Loss function: 2.8139e+07
# MAPE: 0.108758
# RMSE: 5.97882
#
# Iter: 340
# Loss function: 2.79753e+07
# MAPE: 0.107945
# RMSE: 5.952
#
# Iter: 350
# Loss function: 2.78105e+07
# MAPE: 0.107218
# RMSE: 5.92533
#
# Iter: 360
# Loss function: 2.76339e+07
# MAPE: 0.106514
# RMSE: 5.8969
#
# Iter: 370
# Loss function: 2.74461e+07
# MAPE: 0.10581
# RMSE: 5.86663
#
# Iter: 380
# Loss function: 2.72555e+07
# MAPE: 0.105107
# RMSE: 5.83576
#
# Iter: 390
# Loss function: 2.70717e+07
# MAPE: 0.104427
# RMSE: 5.80582
#
# Iter: 400
# Loss function: 2.68993e+07
# MAPE: 0.10378
# RMSE: 5.77762
#
# Iter: 410
# Loss function: 2.67359e+07
# MAPE: 0.103163
# RMSE: 5.75082
#
# Iter: 420
# Loss function: 2.65742e+07
# MAPE: 0.102552
# RMSE: 5.72425
#
# Iter: 430
# Loss function: 2.64067e+07
# MAPE: 0.10192
# RMSE: 5.69658
#
# Iter: 440
# Loss function: 2.62294e+07
# MAPE: 0.101251
# RMSE: 5.66706
#
# Iter: 450
# Loss function: 2.60437e+07
# MAPE: 0.10054
# RMSE: 5.63578
#
# Iter: 460
# Loss function: 2.58556e+07
# MAPE: 0.0998056
# RMSE: 5.60373
#
# Iter: 470
# Loss function: 2.56739e+07
# MAPE: 0.0990747
# RMSE: 5.57241
#
# Iter: 480
# Loss function: 2.55068e+07
# MAPE: 0.09838
# RMSE: 5.54329
#
# Iter: 490
# Loss function: 2.53589e+07
# MAPE: 0.0977444
# RMSE: 5.51729
#
# Iter: 500
# Loss function: 2.52305e+07
# MAPE: 0.0971808
# RMSE: 5.49461
#
# Iter: 510
# Loss function: 2.51186e+07
# MAPE: 0.0966862
# RMSE: 5.4748
#
# Iter: 520
# Loss function: 2.50188e+07
# MAPE: 0.096249
# RMSE: 5.45713
#
# Iter: 530
# Loss function: 2.49269e+07
# MAPE: 0.0958547
# RMSE: 5.4409
#
# Iter: 540
# Loss function: 2.48401e+07
# MAPE: 0.0954916
# RMSE: 5.42559
#
# Iter: 550
# Loss function: 2.47572e+07
# MAPE: 0.0951534
# RMSE: 5.41096
#
# Iter: 560
# Loss function: 2.46779e+07
# MAPE: 0.094838
# RMSE: 5.39696
#
# Iter: 570
# Loss function: 2.46024e+07
# MAPE: 0.0945454
# RMSE: 5.38364
#
# Iter: 580
# Loss function: 2.45311e+07
# MAPE: 0.0942751
# RMSE: 5.37107
#
# Iter: 590
# Loss function: 2.44638e+07
# MAPE: 0.0940263
# RMSE: 5.35924
#
# Iter: 600
# Loss function: 2.44002e+07
# MAPE: 0.0937958
# RMSE: 5.34811
#
# Iter: 610
# Loss function: 2.43401e+07
# MAPE: 0.0935808
# RMSE: 5.3376
#
# Iter: 620
# Loss function: 2.4283e+07
# MAPE: 0.0933787
# RMSE: 5.32764
#
# Iter: 630
# Loss function: 2.42286e+07
# MAPE: 0.0931865
# RMSE: 5.31816
#
# Iter: 640
# Loss function: 2.4177e+07
# MAPE: 0.0930038
# RMSE: 5.30915
#
# Iter: 650
# Loss function: 2.41284e+07
# MAPE: 0.0928311
# RMSE: 5.30066
#
# Iter: 660
# Loss function: 2.40832e+07
# MAPE: 0.0926692
# RMSE: 5.29274
#
# Iter: 670
# Loss function: 2.40419e+07
# MAPE: 0.0925194
# RMSE: 5.28548
#
# Iter: 680
# Loss function: 2.40048e+07
# MAPE: 0.0923831
# RMSE: 5.27894
#
# Iter: 690
# Loss function: 2.39722e+07
# MAPE: 0.0922611
# RMSE: 5.27317
#
# Iter: 700
# Loss function: 2.3944e+07
# MAPE: 0.092154
# RMSE: 5.26819
#
# Iter: 710
# Loss function: 2.39202e+07
# MAPE: 0.0920609
# RMSE: 5.26397
#
# Iter: 720
# Loss function: 2.39002e+07
# MAPE: 0.0919816
# RMSE: 5.26044
#
# Iter: 730
# Loss function: 2.38837e+07
# MAPE: 0.0919139
# RMSE: 5.25752
#
# Iter: 740
# Loss function: 2.38701e+07
# MAPE: 0.0918566
# RMSE: 5.25512
#
# Iter: 750
# Loss function: 2.38589e+07
# MAPE: 0.091808
# RMSE: 5.25315
#
# Iter: 760
# Loss function: 2.38496e+07
# MAPE: 0.0917669
# RMSE: 5.25151
#
# Iter: 770
# Loss function: 2.38418e+07
# MAPE: 0.0917317
# RMSE: 5.25014
#
# Iter: 780
# Loss function: 2.38352e+07
# MAPE: 0.0917013
# RMSE: 5.24897
#
# Iter: 790
# Loss function: 2.38295e+07
# MAPE: 0.0916743
# RMSE: 5.24796
#
# Iter: 800
# Loss function: 2.38246e+07
# MAPE: 0.0916505
# RMSE: 5.24707
#
# Iter: 810
# Loss function: 2.38202e+07
# MAPE: 0.091629
# RMSE: 5.24627
#
# Iter: 820
# Loss function: 2.38163e+07
# MAPE: 0.0916091
# RMSE: 5.24555
#
# Iter: 830
# Loss function: 2.38128e+07
# MAPE: 0.0915907
# RMSE: 5.2449
#
# Iter: 840
# Loss function: 2.38096e+07
# MAPE: 0.0915735
# RMSE: 5.24429
#
# Iter: 850
# Loss function: 2.38067e+07
# MAPE: 0.0915576
# RMSE: 5.24372
#
# Iter: 860
# Loss function: 2.3804e+07
# MAPE: 0.0915428
# RMSE: 5.2432
#
# Iter: 870
# Loss function: 2.38016e+07
# MAPE: 0.0915291
# RMSE: 5.2427
#
# Iter: 880
# Loss function: 2.37992e+07
# MAPE: 0.0915162
# RMSE: 5.24223
#
# Iter: 890
# Loss function: 2.37971e+07
# MAPE: 0.091504
# RMSE: 5.24179
#
# Iter: 900
# Loss function: 2.37951e+07
# MAPE: 0.0914923
# RMSE: 5.24137

# %% [markdown]
# #### Matrix Factorization with SGD

# %%
import numpy as np
np.random.seed(1000)

dense_tensor = np.load('../datasets/Seattle-data-set/tensor.npz')['arr_0']
dim = dense_tensor.shape
missing_rate = 0.6 # Random missing (RM)
sparse_tensor = dense_tensor * np.round(np.random.rand(dim[0], dim[1], dim[2]) + 0.5 - missing_rate)
dense_mat = dense_tensor.reshape([dim[0], dim[1] * dim[2]])
sparse_mat = sparse_tensor.reshape([dim[0], dim[1] * dim[2]])
del dense_tensor, sparse_tensor

import time
start = time.time()
R = 10
rho = 1e+2
maxiter = 1000
mat_hat, obj_sgd = MF_sgd(dense_mat, sparse_mat, R, rho, maxiter)
end = time.time()
print('Running time: %d seconds.'%(end - start))

# %% [markdown]
# #### Matrix Factorization with ALS

# %%
import numpy as np
np.random.seed(1000)

dense_tensor = np.load('../datasets/Seattle-data-set/tensor.npz')['arr_0']
dim = dense_tensor.shape
missing_rate = 0.6 # Random missing (RM)
sparse_tensor = dense_tensor * np.round(np.random.rand(dim[0], dim[1], dim[2]) + 0.5 - missing_rate)
dense_mat = dense_tensor.reshape([dim[0], dim[1] * dim[2]])
sparse_mat = sparse_tensor.reshape([dim[0], dim[1] * dim[2]])
del dense_tensor, sparse_tensor

import time
start = time.time()
R = 10
rho = 1e+2
maxiter = 200
mat_hat, obj_als = MF_als(dense_mat, sparse_mat, R, rho, maxiter)
end = time.time()
print('Running time: %d seconds.'%(end - start))

# %% [markdown]
# #### Objective Function vs. Iteration

# %%
import matplotlib.pyplot as plt
plt.rcParams['mathtext.fontset'] = 'cm'

show_it = 200
fig = plt.figure(figsize = (4, 3.5))
plt.yscale("log")
plt.plot(obj_gd, 'blue', linewidth = 2.5)
plt.plot(obj_sgd, 'green', linewidth = 2.5)
plt.plot(obj_als, 'red', linewidth = 2.5)
plt.xlim([0, show_it])
plt.xlabel('Iteration')
plt.ylabel(r'Objective function $f$')
plt.legend(['GD', 'SGD', 'ALS'])
plt.savefig("MF_convergence_over_gd_and_als_within_{}iter_Seattle.pdf".format(show_it), 
            format = "pdf", bbox_inches = "tight")
plt.show()

# %% [markdown]
# ## Smoothing Matrix Factorization

# %%
import numpy as np
np.random.randn(1)

def compute_mape(var, var_hat):
    return np.sum(np.abs(var - var_hat) / var) / var.shape[0]

def compute_rmse(var, var_hat):
    return np.sqrt(np.sum((var - var_hat) ** 2) / var.shape[0])

def generate_Psi(n):
    mat1 = np.append(np.zeros((n - 1, 1)), np.eye(n - 1), axis = 1)
    mat2 = np.append(np.eye(n - 1), np.zeros((n - 1, 1)), axis = 1)
    Psi = mat1 - mat2
    return Psi

def update_cg(var, r, q, Aq, rold):
    alpha = rold / np.inner(q, Aq)
    var = var + alpha * q
    r = r - alpha * Aq
    rnew = np.inner(r, r)
    q = r + (rnew / rold) * q
    return var, r, q, rnew

def ell_w(ind, W, X, Psi1, rho, lmbda):
    return X @ ((W.T @ X) * ind).T + rho * W + lmbda * W @ Psi1.T @ Psi1

def conj_grad_w(sparse_mat, ind, W, X, Psi1, rho, lmbda, maxiter = 5):
    rank, dim1 = W.shape
    w = np.reshape(W, -1, order = 'F')
    r = np.reshape(X @ sparse_mat.T 
                   - ell_w(ind, W, X, Psi1, rho, lmbda), -1, order = 'F')
    q = r.copy()
    rold = np.inner(r, r)
    for it in range(maxiter):
        Q = np.reshape(q, (rank, dim1), order = 'F')
        Aq = np.reshape(ell_w(ind, Q, X, Psi1, rho, lmbda), -1, order = 'F')
        w, r, q, rold = update_cg(w, r, q, Aq, rold)
    return np.reshape(w, (rank, dim1), order = 'F')

def ell_x(ind, W, X, Psi2, rho, lmbda):
    return W @ ((W.T @ X) * ind) + rho * X + lmbda * X @ Psi2.T @ Psi2

def conj_grad_x(sparse_mat, ind, W, X, Psi2, rho, lmbda, maxiter = 5):
    rank, dim2 = X.shape
    x = np.reshape(X, -1, order = 'F')
    r = np.reshape(W @ sparse_mat 
                   - ell_x(ind, W, X, Psi2, rho, lmbda), -1, order = 'F')
    q = r.copy()
    rold = np.inner(r, r)
    for it in range(maxiter):
        Q = np.reshape(q, (rank, dim2), order = 'F')
        Aq = np.reshape(ell_x(ind, W, Q, Psi2, rho, lmbda), -1, order = 'F')
        x, r, q, rold = update_cg(x, r, q, Aq, rold)
    return np.reshape(x, (rank, dim2), order = 'F')

def SMF(dense_mat, sparse_mat, rank, rho, lmbda, maxiter = 50):
    dim1, dim2 = sparse_mat.shape
    W = 0.01 * np.random.randn(rank, dim1)
    X = 0.01 * np.random.randn(rank, dim2)
    if np.isnan(sparse_mat).any() == False:
        ind = sparse_mat != 0
        pos_test = np.where((dense_mat != 0) & (sparse_mat == 0))
    elif np.isnan(sparse_mat).any() == True:
        ind = ~np.isnan(sparse_mat)
        pos_test = np.where((dense_mat > 0) & (np.isnan(sparse_mat)))
        sparse_mat[np.isnan(sparse_mat)] = 0
    Psi1 = generate_Psi(dim1)
    Psi2 = generate_Psi(dim2)
    show_iter = 10
    for it in range(maxiter):
        W = conj_grad_w(sparse_mat, ind, W, X, Psi1, rho, lmbda)
        X = conj_grad_x(sparse_mat, ind, W, X, Psi2, rho, lmbda)
        mat_hat = W.T @ X
        if (it + 1) % show_iter == 0:
            print('Iter: {}'.format(it + 1))
            print('MAPE: {:.6}'.format(compute_mape(dense_mat[pos_test], 
                                                    mat_hat[pos_test])))
            print('RMSE: {:.6}'.format(compute_rmse(dense_mat[pos_test], 
                                                    mat_hat[pos_test])))
            print()
    return mat_hat

# %% [markdown]
# ### Speed Field Reconstruction

# %%
import numpy as np
np.random.seed(1)

import matplotlib.pyplot as plt
import seaborn as sns
import imageio as io
plt.rcParams['font.size'] = 12

dense_mat = np.load('../datasets/NGSIM-data-set/NGSIM_full.npy')
sparse_mat = np.load('../datasets/NGSIM-data-set/NGSIM_80missing.npy')

def plot_speed_field(data, filename):
    fig = plt.figure(figsize = (2.5 * 2.5, 2.5))
    plt.matshow(data, cmap='jet_r', origin='lower', 
                vmin = 0, vmax = 25, fignum = 1)
    plt.gca().xaxis.set_ticks_position('bottom')
    plt.xticks([0, 100, 200, 300, 400, 500], [0, 500, 1000, 1500, 2000, 2500])
    plt.yticks([0, 100, 200], [0, 300, 600])
    plt.xlabel('Time (s)')
    plt.ylabel('Location (m)')
    cbar = plt.colorbar(fraction = 0.015)
    cbar.ax.set_ylabel('Speed (mph)')
    plt.show()
    fig.savefig(filename, bbox_inches = 'tight', dpi = 300)

plot_speed_field(dense_mat, 'speed_field_fully_data.png')
plot_speed_field(sparse_mat, 'speed_field_80_missing_data.png')

import time
start = time.time()
R = 10
rho = 1e+1
lmbda = 1e+2
maxiter = 200
mat_hat = SMF(dense_mat, sparse_mat, R, rho, lmbda, maxiter)
end = time.time()
print('Running time: %d seconds.'%(end - start))
plot_speed_field(mat_hat, 'speed_field_SMF_rec_lambda_{}.png'.format(int(lmbda)))

# %% [markdown]
# ### Seattle Freeway Traffic Speed Imputation

# %%
import numpy as np
np.random.seed(1000)

dense_tensor = np.load('../datasets/Seattle-data-set/tensor.npz')['arr_0']
dim = dense_tensor.shape
missing_rate = 0.6 # Random missing (RM)
sparse_tensor = dense_tensor * np.round(np.random.rand(dim[0], dim[1], dim[2]) + 0.5 - missing_rate)
dense_mat = dense_tensor.reshape([dim[0], dim[1] * dim[2]])
sparse_mat = sparse_tensor.reshape([dim[0], dim[1] * dim[2]])
del dense_tensor, sparse_tensor

import time
start = time.time()
R = 10
rho = 1e+2
lmbda = 5e+2
maxiter = 200
mat_hat = SMF(dense_mat, sparse_mat, R, rho, lmbda, maxiter)
end = time.time()
print('Running time: %d seconds.'%(end - start))

# %% [markdown]
# ## Hankel Tensor Factorization

# %%
import numpy as np
np.random.randn(1)

def compute_mape(var, var_hat):
    return np.sum(np.abs(var - var_hat) / var) / var.shape[0]

def compute_rmse(var, var_hat):
    return np.sqrt(np.sum((var - var_hat) ** 2) / var.shape[0])

def hankel(matrix, tau):
    N, T = matrix.shape
    tensor = np.zeros((N, T - tau + 1, tau))
    for k in range(tau):
        tensor[:, :, k] = matrix[:, k : T - tau + k + 1]
    return tensor

def inv_hankel(tensor):
    N, dim, tau = tensor.shape
    T = dim + tau - 1
    matrix = np.zeros((N, T))
    binary = np.zeros((N, T))
    for k in range(tau):
        temp1 = np.zeros((N, T))
        temp1[:, k : dim + k] = tensor[:, :, k]
        temp2 = np.zeros((N, T))
        temp2[:, k : dim + k] = 1
        matrix += temp1
        binary += temp2
    return matrix / binary

def ten2mat(tensor, mode):
    return np.reshape(np.moveaxis(tensor, mode, 0), (tensor.shape[mode], -1), order = 'F')

def kr_prod(a, b):
    return np.einsum('ir, jr -> ijr', a, b).reshape(a.shape[0] * b.shape[0], -1)

def update_cg(var, r, q, Aq, rold):
    alpha = rold / np.inner(q, Aq)
    var = var + alpha * q
    r = r - alpha * Aq
    rnew = np.inner(r, r)
    q = r + (rnew / rold) * q
    return var, r, q, rnew

def ell(ind_mode, f_mat, mat):
    return ((f_mat @ mat.T) * ind_mode) @ mat

def conj_grad(sparse_tensor, ind, fact_mat, mode, maxiter = 5):
    dim, rank = fact_mat[mode].shape
    ind_mode = ten2mat(ind, mode)
    f = np.reshape(fact_mat[mode], -1, order = 'F')
    temp = []
    for k in range(3):
        if k != mode:
            temp.append(fact_mat[k])
    mat = kr_prod(temp[-1], temp[0])
    r = np.reshape(ten2mat(sparse_tensor, mode) @ mat
                   - ell(ind_mode, fact_mat[mode], mat), -1, order = 'F')
    q = r.copy()
    rold = np.inner(r, r)
    for it in range(maxiter):
        Q = np.reshape(q, (dim, rank), order = 'F')
        Aq = np.reshape(ell(ind_mode, Q, mat), -1, order = 'F')
        alpha = rold / np.inner(q, Aq)
        f, r, q, rold = update_cg(f, r, q, Aq, rold)
    return np.reshape(f, (dim, rank), order = 'F')

def HTF(dense_mat, sparse_mat, tau, rank, rho, maxiter = 50):
    if np.isnan(sparse_mat).any() == False:
        pos_test = np.where((dense_mat != 0) & (sparse_mat == 0))
    elif np.isnan(sparse_mat).any() == True:
        pos_test = np.where((dense_mat > 0) & (np.isnan(sparse_mat)))
        sparse_mat[np.isnan(sparse_mat)] = 0
    sparse_tensor = hankel(sparse_mat, tau)
    dim = sparse_tensor.shape
    fact_mat = []
    for k in range(3):
        fact_mat.append(0.01 * np.random.randn(dim[k], rank))
    ind = sparse_tensor != 0
    show_iter = 10
    for it in range(maxiter):
        for k in range(3):
            fact_mat[k] = conj_grad(sparse_tensor, ind, fact_mat, k)
        tensor_hat = np.einsum('ur, vr, xr -> uvx', 
                               fact_mat[0], fact_mat[1], fact_mat[2])
        mat_hat = inv_hankel(tensor_hat)
        if (it + 1) % show_iter == 0:
            print('Iter: {}'.format(it + 1))
            print('MAPE: {:.6}'.format(compute_mape(dense_mat[pos_test], 
                                                    mat_hat[pos_test])))
            print('RMSE: {:.6}'.format(compute_rmse(dense_mat[pos_test], 
                                                    mat_hat[pos_test])))
            print()
    return mat_hat

# %% [markdown]
# ### Speed Field Reconstruction

# %%
import numpy as np
np.random.seed(1)

import matplotlib.pyplot as plt
import seaborn as sns
import imageio as io
plt.rcParams['font.size'] = 12

dense_mat = np.load('NGSIM_full.npy')
sparse_mat = np.load('NGSIM_80missing.npy')

def plot_speed_field(data, filename):
    fig = plt.figure(figsize = (2.5 * 2.5, 2.5))
    plt.matshow(data, cmap='jet_r', origin='lower', 
                vmin = 0, vmax = 25, fignum = 1)
    plt.gca().xaxis.set_ticks_position('bottom')
    plt.xticks([0, 100, 200, 300, 400, 500], [0, 500, 1000, 1500, 2000, 2500])
    plt.yticks([0, 100, 200], [0, 300, 600])
    plt.xlabel('Time (s)')
    plt.ylabel('Location (m)')
    cbar = plt.colorbar(fraction = 0.015)
    cbar.ax.set_ylabel('Speed (mph)')
    plt.show()
    fig.savefig(filename, bbox_inches = 'tight', dpi = 300)

plot_speed_field(dense_mat, 'speed_field_fully_data.png')
plot_speed_field(sparse_mat, 'speed_field_80_missing_data.png')

import time
start = time.time()
tau = 10
R = 10
rho = 1e+1
maxiter = 200
mat_hat = HTF(dense_mat, sparse_mat, tau, R, rho, maxiter)
end = time.time()
print('Running time: %d seconds.'%(end - start))
plot_speed_field(mat_hat, 'speed_field_HTF_rec_tau_{}.png'.format(int(tau)))

# %% [markdown]
# ### Seattle Freeway Traffic Speed Imputation

# %%
import numpy as np
np.random.seed(1000)

dense_tensor = np.load('../datasets/Seattle-data-set/tensor.npz')['arr_0']
dim = dense_tensor.shape
missing_rate = 0.6 # Random missing (RM)
sparse_tensor = dense_tensor * np.round(np.random.rand(dim[0], dim[1], dim[2]) + 0.5 - missing_rate)
dense_mat = dense_tensor.reshape([dim[0], dim[1] * dim[2]])
sparse_mat = sparse_tensor.reshape([dim[0], dim[1] * dim[2]])
del dense_tensor, sparse_tensor

import time
start = time.time()
tau = 6
R = 10
rho = 1e+2
maxiter = 200
mat_hat = HTF(dense_mat, sparse_mat, tau, R, rho, maxiter)
end = time.time()
print('Running time: %d seconds.'%(end - start))

# %% [markdown]
# ## Dynamic System (Fluid Flow)
#
# The dataset is available at [https://github.com/xinychen/vars/tree/main/datasets/fluid-flow](https://github.com/xinychen/vars/tree/main/datasets/fluid-flow).

# %%
import numpy as np
import seaborn as sns
import scipy.io
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
color = scipy.io.loadmat('CCcool.mat')
cc = color['CC']
newcmp = LinearSegmentedColormap.from_list('', cc)

tensor = np.load('tensor.npz')['arr_0']
tensor = tensor[:, :, : 150]
M, N, T = tensor.shape

plt.rcParams['font.size'] = 13
plt.rcParams['mathtext.fontset'] = 'cm'
fig = plt.figure(figsize = (12, 4))
id = np.array([5, 10, 15, 20, 25, 30, 35, 40])
for t in range(8):
    ax = fig.add_subplot(2, 4, t + 1)
    ax = sns.heatmap(tensor[:, :, id[t] - 1], cmap = newcmp, vmin = -5, vmax = 5, cbar = False)
    ax.contour(np.linspace(0, N, N), np.linspace(0, M, M), tensor[:, :, id[t] - 1],
               levels = np.linspace(0.15, 15, 30), colors = 'k', linewidths = 0.7)
    ax.contour(np.linspace(0, N, N), np.linspace(0, M, M), tensor[:, :, id[t] - 1],
               levels = np.linspace(-15, -0.15, 30), colors = 'k', linestyles = 'dashed', linewidths = 0.7)
    plt.xticks([])
    plt.yticks([])
    plt.title(r'$t = {}$'.format(id[t]))
    for _, spine in ax.spines.items():
        spine.set_visible(True)
plt.show()
fig.savefig('fluid_flow_heatmap_2_times_4.png', bbox_inches = 'tight')

# %% [markdown]
# ### License
#
# <div class="alert alert-block alert-danger">
# <b>This work is released under the MIT license.</b>
# </div>
